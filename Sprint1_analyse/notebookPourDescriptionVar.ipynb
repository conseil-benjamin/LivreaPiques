# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#CSV Import
cleanedDataFrame = pd.read_csv("../new_data/CleanedAuthors.csv", delimiter=",")

## affiché chaque variable avec son type
for column in cleanedDataFrame.columns:
    print(column, cleanedDataFrame[column].dtype, cleanedDataFrame[column].head(1).values)

## verifier si author_rating_count est le même pour chaque ligne d'un même auteur
display(cleanedDataFrame.loc[cleanedDataFrame['author_name'] == 'J.K. Rowling'])
# Out:
# Unnamed: 0 int64 [0]
# author_average_rating float64 [4.01]
# author_gender object ['female']
# author_genres object ['historical-fiction,']
# author_id int64 [74489]
# author_name object ['Victoria Thompson']
# author_rating_count int64 [74399]
# author_review_count int64 [6268]
# birthplace object [' United States']
# book_average_rating float64 [4.02]
# book_id object ['686717']
# book_title object ["Murder on St. Mark's Place"]
# genre_1 object ['Mystery']
# genre_2 object ['Historical']
# num_ratings int64 [5260]
# num_reviews int64 [375]
# pages object ['277']
# publish_date object ['2000']
#        Unnamed: 0  author_average_rating author_gender author_genres  \
# 128           128                   4.45        female      fiction,
# 3040         3040                   4.45        female      fiction,
# 6497         6497                   4.45        female      fiction,
# 10659       10659                   4.45        female      fiction,
# ...

# %%
# savoir se qu'est la colonne 'Unnamed: 0'
display(cleanedDataFrame['Unnamed: 0'].head(3))
# pareil pour pages
display(cleanedDataFrame['pages'].head(3))
# Out:
# 0    0
# 1    1
# 2    2
# Name: Unnamed: 0, dtype: int64
# 0    277
# 1    465
# 2    354
# Name: pages, dtype: object

# %%
bookdf = pd.read_csv("bigboss_book.csv", delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 bookdf = pd.read_csv("bigboss_book.csv", delimiter=",")
#
# File /usr/local/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
## aficher un tableau avec le nom de variables, leur type et leur première valeur du dataframe bookdf
for column in bookdf.columns:
    print(column, bookdf[column].dtype, bookdf[column].head(1).values)
# Out:
# id int64 [630104]
# title object ['Inner Circle']
# series object ['(Private #5)']
# author object ['Kate Brian, Julian Peploe']
# rating_count int64 [7597]
# review_count int64 [196]
# average_rating object ['4,03']
# five_star_ratings int64 [3045]
# four_star_ratings int64 [2323]
# three_star_ratings int64 [1748]
# two_star_ratings int64 [389]
# one_star_ratings int64 [92]
# number_of_pages float64 [220.]
# date_published object ['January 1st 2007']
# publisher object ['Simon  Schuster Books for Young Readers']
# original_title object ['Inner Circle']
# genre_and_votes object ['Young Adult 161, Mystery 45, Romance 32']
# isbn object ['1416950419']
# isbn13 object ['9781416950417']
# settings object [nan]
# characters object [nan]
# awards object [nan]
# books_in_series object ['381489, 381501, 352428, 630103, 1783281, 1783289, 2206960, 3997399, 5995900, 6693415']
# ...

# %%
## afficher les 10 premières lignes de bookdf
selected_columns = bookdf.iloc[:, 21:35]
display(selected_columns.head(10))
# Out:
#                                               awards  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Independent Publisher Book Award (IPPY) Nomine...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                      books_in_series  \
# 0  381489, 381501, 352428, 630103, 1783281, 17832...
# 1                                             115036
# 2                         4010795, 40792877, 7306261
# 3  67035, 39031, 39033, 136637, 136638, 30068, 39...
# 4                                                NaN
# 5                                                NaN
# ...

# %%
## lister la liste des valeur de la variable genre_1 et genre_2
print(cleanedDataFrame['genre_1'].unique())
print(cleanedDataFrame['genre_2'].unique())
# Out:
# ['Mystery' 'Fiction' 'Romance' 'Fantasy' 'Sequential Art' 'Young Adult'
#  'Nonfiction' 'Paranormal' 'Historical' 'Science Fiction' 'Horror'
#  'Classics' 'Autobiography' 'Womens Fiction' 'New Adult' 'Contemporary'
#  'Humor' 'History' 'Childrens' 'Lgbt' 'Sports and Games' 'War' 'Dark'
#  'Philosophy' 'Poetry' 'Christian' 'Adventure' 'Anthologies'
#  'Christian Fiction' 'Warfare' 'Erotica' 'Biography' 'Adult Fiction'
#  'Short Stories' 'Animals' 'Science' 'Shapeshifters' 'Self Help'
#  'Politics' 'Music' 'Religion' 'Plays' 'Mental Health' 'Thriller' 'Crime'
#  'Mythology' 'Travel' 'Military History' 'Language' 'Literature'
#  'Psychology' 'Novels' 'Feminism' 'Economics' 'Business' 'Media Tie In'
#  'World War II' 'Cultural' 'Science Fiction Fantasy' 'Death' 'Lds'
#  'Northern Africa' 'Design' 'Magical Realism' 'Apocalyptic'
#  'Realistic Fiction' 'Asian Literature' 'Spy Thriller' 'Suspense'
#  'Holiday' 'Category Romance' 'Spirituality' 'Dungeons and Dragons'
# ...
